# %%
# packages needed
import pandas as pd

# %%
df = pd.read_csv('data/evdataset.csv')

# %%
df.head()
# Out:
#      id        Make                                               link  \
# 0  1647     Genesis  https://ev-database.org/car/1647/Genesis-GV60-...
# 1  1493    Mercedes  https://ev-database.org/car/1493/Mercedes-EQB-...
# 2  1229     Porsche  https://ev-database.org/car/1229/Porsche-Tayca...
# 3  1252         BMW   https://ev-database.org/car/1252/BMW-i4-eDrive40
# 4  1534  Volkswagen  https://ev-database.org/car/1534/Volkswagen-ID...
#
#    City - Cold Weather  Highway - Cold Weather  Combined - Cold Weather  \
# 0                  390                     275                      330
# 1                  330                     235                      280
# 2                  400                     305                      350
# 3                  445                     340                      390
# 4                  440                     320                      380
#
#    City - Mild Weather  Highway - Mild Weather  Combined - Mild Weather  \
# ...

# %%
df.tail()
# Out:
#        id        Make                                               link  \
# 189  1116     Porsche  https://ev-database.org/car/1116/Porsche-Tayca...
# 190  1533  Volkswagen  https://ev-database.org/car/1533/Volkswagen-ID...
# 191  1547     Citroen  https://ev-database.org/car/1547/Citroen-e-Ber...
# 192  1492        Audi  https://ev-database.org/car/1492/Audi-Q4-Sport...
# 193  1353     Peugeot  https://ev-database.org/car/1353/Peugeot-e-Tra...
#
#      City - Cold Weather  Highway - Cold Weather  Combined - Cold Weather  \
# 189                  390                     290                      340
# 190                  440                     320                      380
# 191                  210                     140                      170
# 192                  395                     290                      340
# 193                  285                     185                      230
#
#      City - Mild Weather  Highway - Mild Weather  Combined - Mild Weather  \
# ...

# %%
df.columns
# Out:
# Index(['id', 'Make', 'link', 'City - Cold Weather', 'Highway - Cold Weather',
#        'Combined - Cold Weather', 'City - Mild Weather',
#        'Highway - Mild Weather', 'Combined - Mild Weather',
#        'Acceleration 0 - 100 km/h', 'Top Speed', 'Electric Range',
#        'Total Power', 'Total Torque', 'Drive', 'Battery Capacity',
#        'Charge Power', 'Charge Speed', 'Fastcharge Speed', 'Length', 'Width',
#        'Height', 'Wheelbase', 'Gross Vehicle Weight (GVWR)', 'Max. Payload',
#        'Cargo Volume', 'Seats'],
#       dtype='object')

# %%
df.describe()
# Out:
#                 id  City - Cold Weather  Highway - Cold Weather  \
# count   194.000000           194.000000              194.000000
# mean   1526.257732           343.247423              247.500000
# std     154.958947            92.173078               75.553656
# min    1116.000000           135.000000               95.000000
# 25%    1437.250000           280.000000              185.000000
# 50%    1557.500000           350.000000              250.000000
# 75%    1648.750000           403.750000              295.000000
# max    1757.000000           595.000000              470.000000
#
#        Combined - Cold Weather  City - Mild Weather  Highway - Mild Weather  \
# count               194.000000           194.000000              194.000000
# mean                293.144330           502.706186              315.721649
# std                  84.558652           138.297461               98.967440
# min                 115.000000           210.000000              125.000000
# ...

# %%
df.value_counts()
# Out:
# id    Make        link                                                                     City - Cold Weather  Highway - Cold Weather  Combined - Cold Weather  City - Mild Weather  Highway - Mild Weather  Combined - Mild Weather  Acceleration 0 - 100 km/h  Top Speed  Electric Range  Total Power  Total Torque  Drive  Battery Capacity  Charge Power  Charge Speed  Fastcharge Speed  Length  Width  Height  Wheelbase  Gross Vehicle Weight (GVWR)  Max. Payload  Cargo Volume  Seats
# 1116  Porsche     https://ev-database.org/car/1116/Porsche-Taycan-Turbo-S                  390                  290                     340                      560                  370                     450                      2.8                        260        400             560          1050          AWD    93.4              11.0          45            980               4963    1966   1378    2900       2870                         575           366           4        1
# ...
